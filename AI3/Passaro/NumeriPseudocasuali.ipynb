# %%
import numpy as np
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
import numpy as np
np.random.default_rng()
# Out:
# Generator(PCG64) at 0x7AF7DC341C40

# %%
from numpy.random import default_rng
rng = default_rng(42)
rng.normal(size=5)
# Out:
# array([ 0.30471708, -1.03998411,  0.7504512 ,  0.94056472, -1.95103519])
