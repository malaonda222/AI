# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter 

s_due_dadi = {(i, j) for i in range(1, 7) for j in range(1, 7)}
s_due_dadi_list = list(s_due_dadi)

print(f"Spazio campionario per due dadi:")
print(f"Cardinalità |S| = {len(s_due_dadi_list)}")
print(f"\nPrimi 10 elementi: {s_due_dadi_list[:10]}")
print(f"\nUltimi 10 elementi: {s_due_dadi_list[-10:]}")

s_dado = {1, 2, 3, 4, 5, 6}
print(f"\nSpazio campionario S = {s_dado}")
print(f"Cardinalità |S| = {len(s_dado)}")

n_lanci = 1000
lanci = np.random.randint(1, 7, size=n_lanci)

frequenze = Counter(lanci)
print(f"\nFrequenze assolute dopo {n_lanci} lanci:")
for faccia in sorted(frequenze.keys()):
    freq_rel = frequenze[faccia] / n_lanci 
    print(f"    Faccia {faccia}: {frequenze[faccia]} volte (frequenza relativa: {freq_rel:.3f})")


# Visualizzazione delle frequenze 
plt.figure(figsize=(10,6))
facce = sorted(frequenze.keys())
conteggi = [frequenze[f] for f in facce]

plt.bar(facce, conteggi, color='steelblue', label='Frequenze')
plt.legend()
plt.grid(axis='y', alpha= 0.3)
plt.show()
# Out:
# Spazio campionario per due dadi:
# Cardinalità |S| = 36
#
# Primi 10 elementi: [(3, 4), (4, 3), (3, 1), (5, 4), (4, 6), (5, 1), (2, 2), (1, 6), (2, 5), (1, 3)]
#
# Ultimi 10 elementi: [(3, 5), (5, 2), (4, 4), (5, 5), (1, 1), (1, 4), (2, 3), (2, 6), (6, 6), (6, 3)]
#
# Spazio campionario S = {1, 2, 3, 4, 5, 6}
# Cardinalità |S| = 6
#
# Frequenze assolute dopo 1000 lanci:
#     Faccia 1: 176 volte (frequenza relativa: 0.176)
#     Faccia 2: 173 volte (frequenza relativa: 0.173)
#     Faccia 3: 156 volte (frequenza relativa: 0.156)
#     Faccia 4: 167 volte (frequenza relativa: 0.167)
#     Faccia 5: 165 volte (frequenza relativa: 0.165)
#     Faccia 6: 163 volte (frequenza relativa: 0.163)
