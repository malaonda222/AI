# %%
#Simula il lancio di due dadi D6
#Restituisci in putput una lista con n=100 risultati della somma dei due dadi

#parte2
#quale risultato ti aspetti sia più frequente? verifica l'ipotesi

import random 

numero_lanci = 10000
risultati = []
for i in range(numero_lanci):
    dado1 = random.randint(1,6)
    dado2 = random.randint(1,6)
    risultato = dado1 + dado2
    risultati.append(risultato)

frequenza_7 = risultati.count(7)
print("Simulazione", frequenza_7/numero_lanci)
print("Risultato probabilità classica", 6/36)
# Out:
# Simulazione 0.1622
# Risultato probabilità classica 0.16666666666666666
